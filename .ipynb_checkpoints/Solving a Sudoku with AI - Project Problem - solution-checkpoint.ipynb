# %% [markdown]
# ## Table of Content
#
# 1. Project Introduction
# 2. project solve a sudoku with AI
#
# ** Goals of this project **
#
# For this project, you will implement some extensions to the Sudoku algorithm developed in the lectures.
# - The first extension will be an implementation of the naked twins technique.
# - The second will be a modification of the algorithm to solve a diagonal sudoku.
#
# ### <font color='red'> ** 1. Naked Twins Technique ** </font>
#
# The naked twins technique is the following. Consider the following puzzle, and look at the two highlighted boxes, 'F3' and 'I3'.
#
# <img src="images/naked-twins.png" width="40%" height="40%">
#
# As we can see, both belong to the same column, and both permit the values of 2 and 3. Now, we don't know which one has a 2 and which one has a 3, but ** we know one thing for sure — the values 2 and 3 are locked in those two boxes **, so no other box in their same unit (the third column) can contain the values 2 or 3.
#
# ** Thus, we go over all the boxes in their same unit, and remove the values 2 and 3 from their possible values. **
#
# <img src="images/naked-twins-2.png" width="40%" height="40%">
#
# ### <font color='red'> ** 2. Diagonal sudoku ** </font>
#
# A diagonal sudoku is like a regular sudoku, except that among the two main diagonals, the numbers 1 to 9 should all appear exactly once. In this project, you'll modify the functions we've written in the lecture (or you can write your own!) in order to solve every diagonal sudoku.
#
# <img src="images/diagonal-sudoku.png" width="40%" height="40%">

# %% [markdown]
# <a id="cell_encoding_the_board"></a>
# ## Project Submission
#
# ** Overview **
# In this project, you will be writing code to implement two extensions of our sudoku solver. The first one will be to implement the technique called "naked twins". The second one will be to modify our existing code to solve a diagonal sudoku. To complete this project you will use the tools you learned about in the lesson, and build upon them.
#
# ** Your goals are to implement the naked twins function, and write an AI agent that will solve the Diagonal Sudoku game. **

# %%
'''
** Naked twins implementation understanding. **
In the README.md file, the student has shown an understanding of how constraint propagation
has been used to implement the naked twins function, by enforcing the constraint
that no squares outside the two naked twins squares can contain the twin values

** Diagonal Sudoku implementation understanding. **
In the README.md file, the student has shown an understanding of how constraint propagation
has been used to solve the diagonal sudoku, by adding the diagonals to the set of constraints.
'''
import re # Regular Expression

assignments = []

rows = 'ABCDEFGHI'
cols = '123456789'

def cross(A, B):
    "Cross product of elements in A and elements in B."
    return [s + t for s in A for t in B]

boxes = cross(rows, cols)
row_units = [cross(r, cols) for r in rows]
column_units = [cross(rows, c) for c in cols]
square_units = [cross(rs, cs) for rs in ('ABC', 'DEF', 'GHI') for cs in ('123', '456', '789')]
unitlist = row_units + column_units + square_units
units = dict((s, [u for u in unitlist if s in u]) for s in boxes)
peers = dict((s, set(sum(units[s], [])) - set([s])) for s in boxes)

# Create new peers values to include diagonal
diag_units_down = []
diag_units_up = []
row_ind = 1
for row in row_units:
    diag_units_down.append(row[row_ind-1])
    diag_units_up.append(row[len(row)-row_ind])
    row_ind = row_ind+1

for box in diag_units_down:
    peers[box] = list(peers[box])
    peers[box].extend(diag_units_down)
    peers[box].remove(box)
    peers[box] = sorted(set(peers[box]))  # this is to remove duplicate items in list

for box in diag_units_up:
    peers[box] = list(peers[box])
    peers[box].extend(diag_units_up)
    peers[box].remove(box)
    peers[box] = sorted(set(peers[box]))  # this is to remove duplicate items in list

# TODO please make use of this function
def assign_value(values, box, value):
    """
    Please use this function to update your values dictionary!
    Assigns a value to a given box. If it updates the board record it.
    """
    values[box] = value
    if len(value) == 1:
        assignments.append(values.copy())
    return values

def naked_twins(values):
    '''
    In the README.md file, the student has shown an understanding of how constraint propagation
    has been used to implement the naked twins function, by enforcing the constraint
     that no squares outside the two naked twins squares can contain the twin values
    '''

    """Eliminate values using the naked twins strategy.
    Args:
        values(dict): a dictionary of the form {'box_name': '123456789', ...}

    Returns:
        the values dictionary with the naked twins eliminated from peers.
    """
    
    # Find all naked-twin values from the entire grid
    for unit in (unitlist + [diag_units_down] + [diag_units_down]):

        # Collect boxes with 2-digit value as dict temporarily
        twins = {}
        
        # Find twin in each unit
        for box in unit:
            
            value = values[box]
            print("value =",value)

            if len(value) == 2:
                if value in twins:
                    twins[value] = twins[value] + [box]
                else:
                    twins[value] = [box]
                print("twins =",twins) # possible twins
                
        print("twins collection =",twins)
        
        # Eliminate naked twins from the current unit
        for twins_value, boxes_with_twins in twins.items():
            
            # Confirm if there really is a pair of naked twins
            if len(boxes_with_twins) == 2:
                print("************ twin pairs founded!! = ",twins_value,"************")
                display(values)
                
                for box in unit:
                    # Erase naked-twin values from every boxes except the boxes with naked twins
                    if box not in boxes_with_twins:
                        values = assign_value(values, box, values[box].replace(twins_value[0], ''))
                        values = assign_value(values, box, values[box].replace(twins_value[1], ''))
    return values

def cross(A, B):
    "Cross product of elements in A and elements in B."
    return [s + t for s in A for t in B]

def grid_values(grid):
    """
    Convert grid into a dict of {square: char} with '123456789' for empties.
    Args:
        grid(string) - A grid in string form.
    Returns:
        A grid in dictionary form
            Keys: The boxes, e.g., 'A1'
            Values: The value in each box, e.g., '8'. If the box has no value, then the value will be '123456789'.
    """
    
    # check whether input value is in an acceptable format
    assert not re.search("[^.1-9]+", grid) and len(grid) == 81, "grid must contains only number 1-9 and ., and its length must be 81 characters long"
    
    gridList = [char for char in grid] # transform string into list
    gridList = ['123456789' if c=='.' else c for c in gridList] 
    gridList

    return dict(zip(boxes,gridList))

def display(values):
    """
    Display the values as a 2-D grid.
    Args:
        values(dict): The sudoku in dictionary form
    """
    width = 1 + max(len(values[s]) for s in boxes)
    line = '+'.join(['-' * (width * 3)] * 3)
    for r in rows:
        print(''.join(values[r + c].center(width) + ('|' if c in '36' else '')
                      for c in cols))
        if r in 'CF': print(line)
    print

#2. function.py ----------------------------
# 2.1 implement eliminate(values)
# from utils import *
def eliminate(values):
    """Eliminate values from peers of each box with a single value.

    Go through all the boxes, and whenever there is a box with a single value,
    eliminate this value from the set of values of all its peers.

    Args:
        values: Sudoku in dictionary form.
    Returns:
        Resulting Sudoku in dictionary form after eliminating values.
    """
    
    for key,value in values.items():
        # find single values and their associated peers
        if len(value) == 1:
            # use the associated keys to interact with their peers
            for peers_value in peers[key]:
                # remove those duplicated values with replace function
                values[peers_value] = values[peers_value].replace(value,'')
        
    return values 

#2. function.py ----------------------------
# 2.1 implement only_choice(values)
# from utils import *
def only_choice(values):
    """Finalize all values that are the only choice for a unit.

    Go through all the units, and whenever there is a unit with a value
    that only fits in one box, assign the value to this box.

    Input: Sudoku in dictionary form.
    Output: Resulting Sudoku in dictionary form after filling in only choices.
    """
    
    for units_key, units_value in units.items():
        for unit_group in units_value:
            unitValue_concatenate = ""
            for unit in unit_group:
                if unit != units_key:
                    unitValue_concatenate = unitValue_concatenate + values[unit]
            # Seach for the single value from difference belonging to the original unit and assign it
            if len(set(values[units_key]) - set(unitValue_concatenate)) == 1:
                values[units_key] = (set(values[units_key]) - set(unitValue_concatenate)).pop()
            
    return values

#2. function.py ----------------------------
# 2.1 combine the functions eliminate and only_choice to write the function reduce_puzzle
# from utils import *
def reduce_puzzle(values):
    """
    Iterate eliminate() and only_choice(). If at some point, there is a box with no available values, return False.
    If the sudoku is solved, return the sudoku.
    If after an iteration of both functions, the sudoku remains the same, return the sudoku.
    Input: A sudoku in dictionary form.
    Output: The resulting sudoku in dictionary form.
    """
    
    condition = True
    count = 0
    while condition:

        single_value_count_before = len([unit for unit in values.values() if len(unit) == 1])
        
        # Check nakes twins firstly
        values = naked_twins(values) 

        values = eliminate(values)

        values = only_choice(values)

        single_value_count_after = len([unit for unit in values.values() if len(unit) == 1])  

        # Detect the non-values, not even a single one is allowed
        if len([box for box in values.keys() if len(values[box]) == 0]):
            return False

        if single_value_count_after == single_value_count_before:
            condition = False
    
    return values
    
#2. function.py ----------------------------
# 2.1 implement search() using Depth First Search Algorithm
#from utils import *
def search(values):
    "Using depth-first search and propagation, create a search tree and solve the sudoku."
    # First, reduce the puzzle using the previous function
    # Search and Choose one of the unfilled squares with the fewest possibilities
    # Now use recursion to solve each one of the resulting sudokus, 
    # and if one returns a value (not False), return that answer!
    
    # Make sure that all the possibilities have been reduced as much as possible
    values = reduce_puzzle(values)
    
    if values is False:
        return False # Reject early
    if all(len(values[s]) == 1 for s in boxes):
        return values # Sudoku solved
    
    # Search every unfulfilled box with the least number of possibilities    
    least_number, least_unit = 9, ""
    for box in boxes: 
        if (len(values[box]) > 1) and (len(values[box]) <= least_number):
            least_value, least_number, least_unit = values[box],len(values[box]), box
    print("minimum =",least_value,"@",least_unit)
    
    # Use recurrence to solve each one of the sudoku results
    for value in values[least_unit]:    
        print("try",value,"from", values[least_unit],"of",least_unit)
        
        copied_values = values.copy()
        # Alter the specific least unit with the selected value
        copied_values[least_unit] = value
        
        # Recursive function property
        search_attempt = search(copied_values)
        print(search_attempt) # False, None, Values
        
        if search_attempt:
            return search_attempt # Finished
    print("....................")

def solve(grid):
    """
    Find the solution to a Sudoku grid.
    Args:
        grid(string): a string representing a sudoku grid.
            Example: '2.............62....1....7...6..8...3...9...7...6..4...4....8....52.............3'
    Returns:
        The dictionary representation of the final sudoku grid. False if no solution exists.
    """
    
    values = grid_values(grid) # tha main function that sends the grid_values function a str which is returned as dict
    values = search(values) # keep on iterating on the puzzle until it is solved
    return values # the final state of the solved puzzle

if __name__ == '__main__':

    diag_sudoku_grid = '2.............62....1....7...6..8...3...9...7...6..4...4....8....52.............3'
    print("The original Sudoku board is **********************************************")
    display(grid_values(diag_sudoku_grid))
    
    print("\n")
    print("After applying Depth First Search Algorithm (with (1) Naked Twins and (2) Diagonal Constraint) *****")
    display(solve(diag_sudoku_grid))

    try:
        from visualize import visualize_assignments
        visualize_assignments(assignments)

    except SystemExit:
        pass
    except:
        print('We could not visualize your board due to a pygame issue. Not a problem! It is not a requirement.')
# Out:
# The original Sudoku board is **********************************************
#     2     123456789 123456789 |123456789 123456789 123456789 |123456789 123456789 123456789
# 123456789 123456789 123456789 |123456789 123456789     6     |    2     123456789 123456789
# 123456789 123456789     1     |123456789 123456789 123456789 |123456789     7     123456789
# ------------------------------+------------------------------+------------------------------
# 123456789 123456789     6     |123456789 123456789     8     |123456789 123456789 123456789
#     3     123456789 123456789 |123456789     9     123456789 |123456789 123456789     7
# 123456789 123456789 123456789 |    6     123456789 123456789 |    4     123456789 123456789
# ------------------------------+------------------------------+------------------------------
# 123456789     4     123456789 |123456789 123456789 123456789 |    8     123456789 123456789
# 123456789 123456789     5     |    2     123456789 123456789 |123456789 123456789 123456789
# 123456789 123456789 123456789 |123456789 123456789 123456789 |123456789 123456789     3
#
#
# After applying Depth First Search Algorithm (with (1) Naked Twins and (2) Diagonal Constraint) *****
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 6
# value = 2
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 1
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 7
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 6
# value = 123456789
# value = 123456789
# value = 8
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 3
# value = 123456789
# value = 123456789
# value = 123456789
# value = 9
# value = 123456789
# value = 123456789
# value = 123456789
# value = 7
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 6
# value = 123456789
# value = 123456789
# value = 4
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 4
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 8
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 5
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 3
# twins collection = {}
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 3
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 4
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 1
# value = 6
# value = 123456789
# value = 123456789
# value = 123456789
# value = 5
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 6
# value = 123456789
# value = 2
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 9
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 6
# value = 123456789
# value = 8
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 4
# value = 8
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 7
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 7
# value = 123456789
# value = 123456789
# value = 123456789
# value = 3
# twins collection = {}
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 1
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 6
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 7
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 6
# value = 3
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 8
# value = 123456789
# value = 9
# value = 123456789
# value = 6
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 7
# value = 4
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 4
# value = 123456789
# value = 123456789
# value = 123456789
# value = 5
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 123456789
# value = 123456789
# value = 123456789
# value = 2
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# twins collection = {}
# value = 8
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 123456789
# value = 3
# twins collection = {}
# value = 2
# value = 123456789
# value = 1
# value = 123456789
# value = 9
# value = 123456789
# value = 8
# value = 123456789
# value = 3
# twins collection = {}
# value = 2
# value = 123456789
# value = 1
# value = 123456789
# value = 9
# value = 123456789
# value = 8
# value = 123456789
# value = 3
# twins collection = {}
# minimum = 17 @ I1
# try 1 from 17 of I1
# value = 2
# value = 356789
# value = 34789
# value = 1345789
# value = 134578
# value = 134579
# value = 13569
# value = 1345689
# value = 145
# twins collection = {}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 34789
# value = 1345789
# value = 134578
# value = 6
# value = 2
# value = 1345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 45689
# value = 35689
# value = 1
# value = 34589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 45689
# twins collection = {'35': ['C7']}
# value = 14579
# value = 12579
# value = 6
# value = 457
# value = 123457
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 248
# value = 145
# value = 9
# value = 1245
# value = 156
# value = 12568
# value = 7
# twins collection = {}
# value = 15789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 1679
# value = 4
# value = 237
# value = 13579
# value = 13567
# value = 13579
# value = 8
# value = 12569
# value = 12569
# twins collection = {}
# value = 16789
# value = 137
# value = 5
# value = 2
# value = 134678
# value = 13479
# value = 1679
# value = 46
# twins = {'46': ['H8']}
# value = 1469
# twins collection = {'46': ['H8']}
# value = 1
# value = 126789
# value = 2789
# value = 145789
# value = 145678
# value = 14579
# value = 15679
# value = 124569
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 45689
# value = 14579
# value = 3
# value = 15789
# value = 1679
# value = 16789
# value = 1
# twins collection = {}
# value = 356789
# value = 57
# twins = {'57': ['B2']}
# value = 35689
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 137
# value = 126789
# twins collection = {'57': ['B2']}
# value = 34789
# value = 34789
# value = 1
# value = 6
# value = 248
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 1345789
# value = 1345789
# value = 34589
# value = 457
# value = 145
# value = 6
# value = 13579
# value = 2
# value = 145789
# twins collection = {}
# value = 134578
# value = 134578
# value = 23458
# value = 123457
# value = 9
# value = 12357
# value = 13567
# value = 134678
# value = 145678
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 1245
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 14579
# twins collection = {'57': ['F6']}
# value = 13569
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 156
# value = 4
# value = 8
# value = 1679
# value = 15679
# twins collection = {'35': ['C7']}
# value = 1345689
# value = 1345
# value = 7
# value = 12359
# value = 12568
# value = 123589
# value = 12569
# value = 46
# twins = {'46': ['H8']}
# value = 124569
# twins collection = {'46': ['H8']}
# value = 145
# value = 14589
# value = 45689
# value = 1259
# value = 7
# value = 12589
# value = 12569
# value = 1469
# value = 3
# twins collection = {}
# value = 2
# value = 356789
# value = 34789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 34789
# value = 45689
# value = 35689
# value = 1
# twins collection = {'57': ['B2']}
# value = 1345789
# value = 134578
# value = 134579
# value = 1345789
# value = 134578
# value = 6
# value = 34589
# value = 23458
# value = 23459
# twins collection = {}
# value = 13569
# value = 1345689
# value = 145
# value = 2
# value = 1345
# value = 14589
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 45689
# twins collection = {'35': ['C7']}
# value = 14579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 248
# value = 15789
# value = 125789
# value = 2789
# twins collection = {}
# value = 457
# value = 123457
# value = 8
# value = 145
# value = 9
# value = 1245
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# twins collection = {'57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 156
# value = 12568
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 1679
# value = 4
# value = 237
# value = 16789
# value = 137
# value = 5
# value = 1
# value = 126789
# value = 2789
# twins collection = {}
# value = 13579
# value = 13567
# value = 13579
# value = 2
# value = 134678
# value = 13479
# value = 145789
# value = 145678
# value = 14579
# twins collection = {}
# value = 8
# value = 12569
# value = 12569
# value = 1679
# value = 46
# twins = {'46': ['H8']}
# value = 1469
# value = 15679
# value = 124569
# value = 3
# twins collection = {'46': ['H8']}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 457
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 46
# twins = {'57': ['B2', 'F6'], '46': ['H8']}
# value = 3
# twins collection = {'57': ['B2', 'F6'], '46': ['H8']}
# ************ twin pairs founded!! =  57 ************
#    2     356789  34789  |1345789  134578  134579 | 13569  1345689   145
#  45789     57    34789  |1345789  134578    6    |   2      1345   14589
#  45689   35689     1    | 34589   23458   23459  |   35      7     45689
# ------------------------+------------------------+------------------------
#  14579   12579     6    |  457    123457    8    |  1359   12359    1259
#    3      1258    248   |  145      9      1245  |  156    12568     7
#  15789   125789   2789  |   6     12357     57   |   4     123589  12589
# ------------------------+------------------------+------------------------
#   1679     4      237   | 13579   13567   13579  |   8     12569   12569
#  16789    137      5    |   2     134678  13479  |  1679     46     1469
#    1     126789   2789  | 145789  145678  14579  | 15679   124569    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 46
# twins = {'57': ['B2', 'F6'], '46': ['H8']}
# value = 3
# twins collection = {'57': ['B2', 'F6'], '46': ['H8']}
# ************ twin pairs founded!! =  57 ************
#    2     356789  34789  |1345789  134578  134579 | 13569  1345689   145
#  45789     57    34789  |1345789  134578    6    |   2      1345   14589
#  45689   35689     1    | 34589   23458   23459  |   35      7     45689
# ------------------------+------------------------+------------------------
#  14579   12579     6    |   4     123457    8    |  1359   12359    1259
#    3      1258    248   |  145      9      1245  |  156    12568     7
#  15789   125789   2789  |   6     12357     57   |   4     123589  12589
# ------------------------+------------------------+------------------------
#   1679     4      237   | 13579   13567   13579  |   8     12569   12569
#  16789    137      5    |   2     134678  13479  |  1679     46     1469
#    1     126789   2789  | 145789  145678  14579  | 15679   124569    3
# value = 2
# value = 356789
# value = 34789
# value = 135789
# value = 134578
# value = 134579
# value = 13569
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 34789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 45689
# value = 35689
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 6
# twins collection = {'35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 679
# value = 4
# value = 237
# value = 13579
# value = 13567
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {}
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 2
# value = 13478
# value = 13479
# value = 179
# value = 6
# value = 149
# twins collection = {'37': ['H2']}
# value = 1
# value = 26789
# value = 2789
# value = 5789
# value = 45678
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 45689
# value = 579
# value = 3
# value = 5789
# value = 679
# value = 789
# value = 1
# twins collection = {}
# value = 356789
# value = 57
# twins = {'57': ['B2']}
# value = 35689
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 37
# twins = {'57': ['B2'], '37': ['H2']}
# value = 26789
# twins collection = {'57': ['B2'], '37': ['H2']}
# value = 34789
# value = 34789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 13567
# value = 13478
# value = 45678
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 13569
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {'35': ['C7']}
# value = 134589
# value = 345
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 356789
# value = 34789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 34789
# value = 45689
# value = 35689
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 13569
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 345
# value = 14589
# value = 35
# twins = {'45': ['A9'], '35': ['C7']}
# value = 7
# value = 6
# twins collection = {'45': ['A9'], '35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 679
# value = 4
# value = 237
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 1
# value = 26789
# value = 2789
# twins collection = {'37': ['H2']}
# value = 13579
# value = 13567
# value = 13579
# value = 2
# value = 13478
# value = 13479
# value = 5789
# value = 45678
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# value = 179
# value = 6
# value = 149
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2    356789 34789 | 135789 134578 134579| 13569  134589   45
#  45789    57   34789 | 135789 134578   6   |   2     345   14589
#  45689  35689    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#   679     4     237  | 13579  13567  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1    26789   2789 |  5789  45678   4579 |  579    2459    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2    356789 34789 | 135789 134578 134579| 13569  134589   45
#  45789    57   34789 | 135789 134578   6   |   2     345   14589
#  45689  35689    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#   679     4     237  | 13579  13567  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1    26789   2789 |  5789  45678   4579 |  579    2459    3
# value = 2
# value = 6
# value = 3789
# value = 135789
# value = 134578
# value = 134579
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 4589
# value = 3589
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 6
# twins collection = {'35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 6
# value = 4
# value = 237
# value = 13579
# value = 13567
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {}
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 2
# value = 13478
# value = 13479
# value = 179
# value = 6
# value = 149
# twins collection = {'37': ['H2']}
# value = 1
# value = 26789
# value = 2789
# value = 5789
# value = 45678
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 4589
# value = 579
# value = 3
# value = 5789
# value = 6
# value = 789
# value = 1
# twins collection = {}
# value = 6
# value = 57
# twins = {'57': ['B2']}
# value = 3589
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 37
# twins = {'57': ['B2'], '37': ['H2']}
# value = 26789
# twins collection = {'57': ['B2'], '37': ['H2']}
# value = 3789
# value = 3789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 13567
# value = 13478
# value = 45678
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 1359
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {'35': ['C7']}
# value = 134589
# value = 345
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 6
# value = 3789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 4589
# value = 3589
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 345
# value = 14589
# value = 35
# twins = {'45': ['A9'], '35': ['C7']}
# value = 7
# value = 6
# twins collection = {'45': ['A9'], '35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 6
# value = 4
# value = 237
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 1
# value = 26789
# value = 2789
# twins collection = {'37': ['H2']}
# value = 13579
# value = 13567
# value = 13579
# value = 2
# value = 13478
# value = 13479
# value = 5789
# value = 45678
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# value = 179
# value = 6
# value = 149
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579  13567  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1    26789   2789 |  5789  45678   4579 |  579    2459    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579  13567  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1    26789   2789 |  5789  45678   4579 |  579    2459    3
# value = 2
# value = 6
# value = 3789
# value = 135789
# value = 134578
# value = 134579
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 4589
# value = 3589
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 6
# twins collection = {'35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 6
# value = 4
# value = 237
# value = 13579
# value = 1357
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {}
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 2
# value = 13478
# value = 13479
# value = 179
# value = 6
# value = 149
# twins collection = {'37': ['H2']}
# value = 1
# value = 2789
# value = 2789
# value = 5789
# value = 6
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 4589
# value = 579
# value = 3
# value = 5789
# value = 6
# value = 789
# value = 1
# twins collection = {}
# value = 6
# value = 57
# twins = {'57': ['B2']}
# value = 3589
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 37
# twins = {'57': ['B2'], '37': ['H2']}
# value = 2789
# twins collection = {'57': ['B2'], '37': ['H2']}
# value = 3789
# value = 3789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 1357
# value = 13478
# value = 6
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 1359
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {'35': ['C7']}
# value = 134589
# value = 345
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 6
# value = 3789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 4589
# value = 3589
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 345
# value = 14589
# value = 35
# twins = {'45': ['A9'], '35': ['C7']}
# value = 7
# value = 6
# twins collection = {'45': ['A9'], '35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 6
# value = 4
# value = 237
# value = 789
# value = 37
# twins = {'37': ['H2']}
# value = 5
# value = 1
# value = 2789
# value = 2789
# twins collection = {'37': ['H2']}
# value = 13579
# value = 1357
# value = 13579
# value = 2
# value = 13478
# value = 13479
# value = 5789
# value = 6
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# value = 179
# value = 6
# value = 149
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579   1357  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579   1357  13579 |   8     1259   1259
#   789     37     5   |   2    13478  13479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# minimum = 37 @ H2
# try 3 from 37 of H2
# value = 2
# value = 6
# value = 3789
# value = 135789
# value = 134578
# value = 134579
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 4589
# value = 3589
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 6
# twins collection = {'35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 6
# value = 4
# value = 237
# value = 13579
# value = 1357
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {}
# value = 789
# value = 3
# value = 5
# value = 2
# value = 13478
# value = 13479
# value = 179
# value = 6
# value = 149
# twins collection = {}
# value = 1
# value = 2789
# value = 2789
# value = 5789
# value = 6
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 4589
# value = 579
# value = 3
# value = 5789
# value = 6
# value = 789
# value = 1
# twins collection = {}
# value = 6
# value = 57
# twins = {'57': ['B2']}
# value = 3589
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 3
# value = 2789
# twins collection = {'57': ['B2']}
# value = 3789
# value = 3789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 1357
# value = 13478
# value = 6
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 1359
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {'35': ['C7']}
# value = 134589
# value = 345
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 6
# value = 3789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 4589
# value = 3589
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 345
# value = 14589
# value = 35
# twins = {'45': ['A9'], '35': ['C7']}
# value = 7
# value = 6
# twins collection = {'45': ['A9'], '35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 6
# value = 4
# value = 237
# value = 789
# value = 3
# value = 5
# value = 1
# value = 2789
# value = 2789
# twins collection = {}
# value = 13579
# value = 1357
# value = 13579
# value = 2
# value = 13478
# value = 13479
# value = 5789
# value = 6
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# value = 179
# value = 6
# value = 149
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579   1357  13579 |   8     1259   1259
#   789     3      5   |   2    13478  13479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2     345   14589
#   4589   3589    1   |  3589  23458  23459 |   35     7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4     237  | 13579   1357  13579 |   8     1259   1259
#   789     3      5   |   2    13478  13479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# value = 2
# value = 6
# value = 3789
# value = 135789
# value = 134578
# value = 134579
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 45
# twins = {'57': ['B2'], '45': ['B8']}
# value = 14589
# twins collection = {'57': ['B2'], '45': ['B8']}
# value = 4589
# value = 589
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 5
# value = 7
# value = 6
# twins collection = {}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 6
# value = 4
# value = 27
# twins = {'27': ['G3']}
# value = 13579
# value = 1357
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {'27': ['G3']}
# value = 789
# value = 3
# value = 5
# value = 2
# value = 1478
# value = 1479
# value = 179
# value = 6
# value = 149
# twins collection = {}
# value = 1
# value = 2789
# value = 2789
# value = 5789
# value = 6
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 4589
# value = 579
# value = 3
# value = 5789
# value = 6
# value = 789
# value = 1
# twins collection = {}
# value = 6
# value = 57
# twins = {'57': ['B2']}
# value = 589
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 3
# value = 2789
# twins collection = {'57': ['B2']}
# value = 3789
# value = 3789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 27
# twins = {'27': ['G3']}
# value = 5
# value = 2789
# twins collection = {'27': ['G3']}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 1357
# value = 1478
# value = 6
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 1479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 1359
# value = 2
# value = 5
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {}
# value = 134589
# value = 45
# twins = {'45': ['B8']}
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {'45': ['B8']}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 6
# value = 3789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 4589
# value = 589
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 45
# twins = {'45': ['A9', 'B8']}
# value = 14589
# value = 5
# value = 7
# value = 6
# twins collection = {'45': ['A9', 'B8']}
# ************ twin pairs founded!! =  45 ************
#    2      6     3789 | 135789 134578 134579|  1359  134589   45
#  45789    57    3789 | 135789 134578   6   |   2      45   14589
#   4589   589     1   |  3589  23458  23459 |   5      7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4      27  | 13579   1357  13579 |   8     1259   1259
#   789     3      5   |   2     1478   1479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 6
# value = 4
# value = 27
# twins = {'27': ['G3']}
# value = 789
# value = 3
# value = 5
# value = 1
# value = 2789
# value = 2789
# twins collection = {'27': ['G3']}
# value = 13579
# value = 1357
# value = 13579
# value = 2
# value = 1478
# value = 1479
# value = 5789
# value = 6
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# value = 179
# value = 6
# value = 149
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  139    1389    45
#  45789    57    3789 | 135789 134578   6   |   2      45    189
#   4589   589     1   |  3589  23458  23459 |          7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4      27  | 13579   1357  13579 |   8     1259   1259
#   789     3      5   |   2     1478   1479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# value = 2
# value = 57
# twins = {'57': ['B2']}
# value = 1
# value = 4
# value = 9
# value = 57
# twins = {'57': ['B2', 'F6']}
# value = 8
# value = 6
# value = 3
# twins collection = {'57': ['B2', 'F6']}
# ************ twin pairs founded!! =  57 ************
#    2      6     3789 | 135789 134578 134579|  139    1389    45
#  45789    57    3789 | 135789 134578   6   |   2      45    189
#   4589   589     1   |  3589  23458  23459 |          7      6
# ---------------------+---------------------+---------------------
#   579   12579    6   |   4    12357    8   |  1359  12359   1259
#    3     1258    4   |   15     9     125  |   6     1258    7
#   5789  125789  2789 |   6    12357    57  |   4    123589 12589
# ---------------------+---------------------+---------------------
#    6      4      27  | 13579   1357  13579 |   8     1259   1259
#   789     3      5   |   2     1478   1479 |  179     6     149
#    1     2789   2789 |  5789    6     4579 |  579    2459    3
# False
# try 7 from 37 of H2
# value = 2
# value = 6
# value = 3789
# value = 135789
# value = 134578
# value = 134579
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# twins collection = {'45': ['A9']}
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 135789
# value = 134578
# value = 6
# value = 2
# value = 345
# value = 14589
# twins collection = {'57': ['B2']}
# value = 4589
# value = 3589
# value = 1
# value = 3589
# value = 23458
# value = 23459
# value = 35
# twins = {'35': ['C7']}
# value = 7
# value = 6
# twins collection = {'35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 4
# value = 12357
# value = 8
# value = 1359
# value = 12359
# value = 1259
# twins collection = {}
# value = 3
# value = 1258
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 1258
# value = 7
# twins collection = {'15': ['E4']}
# value = 5789
# value = 125789
# value = 2789
# value = 6
# value = 12357
# value = 57
# twins = {'57': ['F6']}
# value = 4
# value = 123589
# value = 12589
# twins collection = {'57': ['F6']}
# value = 6
# value = 4
# value = 237
# value = 13579
# value = 1357
# value = 13579
# value = 8
# value = 1259
# value = 1259
# twins collection = {}
# value = 789
# value = 7
# value = 5
# value = 2
# value = 13478
# value = 13479
# value = 179
# value = 6
# value = 149
# twins collection = {}
# value = 1
# value = 2789
# value = 2789
# value = 5789
# value = 6
# value = 4579
# value = 579
# value = 2459
# value = 3
# twins collection = {}
# value = 2
# value = 45789
# value = 4589
# value = 579
# value = 3
# value = 5789
# value = 6
# value = 789
# value = 1
# twins collection = {}
# value = 6
# value = 57
# twins = {'57': ['B2']}
# value = 3589
# value = 12579
# value = 1258
# value = 125789
# value = 4
# value = 7
# value = 2789
# twins collection = {'57': ['B2']}
# value = 3789
# value = 3789
# value = 1
# value = 6
# value = 4
# value = 2789
# value = 237
# value = 5
# value = 2789
# twins collection = {}
# value = 135789
# value = 135789
# value = 3589
# value = 4
# value = 15
# twins = {'15': ['E4']}
# value = 6
# value = 13579
# value = 2
# value = 5789
# twins collection = {'15': ['E4']}
# value = 134578
# value = 134578
# value = 23458
# value = 12357
# value = 9
# value = 12357
# value = 1357
# value = 13478
# value = 6
# twins collection = {}
# value = 134579
# value = 6
# value = 23459
# value = 8
# value = 125
# value = 57
# twins = {'57': ['F6']}
# value = 13579
# value = 13479
# value = 4579
# twins collection = {'57': ['F6']}
# value = 1359
# value = 2
# value = 35
# twins = {'35': ['C7']}
# value = 1359
# value = 6
# value = 4
# value = 8
# value = 179
# value = 579
# twins collection = {'35': ['C7']}
# value = 134589
# value = 345
# value = 7
# value = 12359
# value = 1258
# value = 123589
# value = 1259
# value = 6
# value = 2459
# twins collection = {}
# value = 45
# twins = {'45': ['A9']}
# value = 14589
# value = 6
# value = 1259
# value = 7
# value = 12589
# value = 1259
# value = 149
# value = 3
# twins collection = {'45': ['A9']}
# value = 2
# value = 6
# value = 3789
# value = 45789
# value = 57
# twins = {'57': ['B2']}
# value = 3789
# value = 4589
# value = 3589
# value = 1
# twins collection = {'57': ['B2']}
# value = 135789
# value = 134578
# value = 134579
# value = 135789
# value = 134578
# value = 6
# value = 3589
# value = 23458
# value = 23459
# twins collection = {}
# value = 1359
# value = 134589
# value = 45
# twins = {'45': ['A9']}
# value = 2
# value = 345
# value = 14589
# value = 35
# twins = {'45': ['A9'], '35': ['C7']}
# value = 7
# value = 6
# twins collection = {'45': ['A9'], '35': ['C7']}
# value = 579
# value = 12579
# value = 6
# value = 3
# value = 1258
# value = 4
# value = 5789
# value = 125789
# value = 2789
# twins collection = {}
# value = 4
# value = 12357
# value = 8
# value = 15
# twins = {'15': ['E4']}
# value = 9
# value = 125
# value = 6
# value = 12357
# value = 57
# twins = {'15': ['E4'], '57': ['F6']}
# twins collection = {'15': ['E4'], '57': ['F6']}
# value = 1359
# value = 12359
# value = 1259
# value = 6
# value = 1258
# value = 7
# value = 4
# value = 123589
# value = 12589
# twins collection = {}
# value = 6
# value = 4
# value = 237
# value = 789
# value = 7
# value = 5
# value = 1
# value = 2789
# value = 2789
# twins collection = {}
# value = 13579
# value = 1357
# value = 13579
# value = 2
# value = 13478
# value = 13479
# value = 5789
# value = 6
# value = 4579
# twins collection = {}
# value = 8
# value = 1259
# value = 1259
# ...
# value = 8
# value = 2
# value = 7
# value = 139
# value = 19
# twins = {'39': ['C6'], '19': ['H6']}
# value = 4
# twins collection = {'39': ['C6'], '19': ['H6']}
# value = 39
# twins = {'39': ['A7']}
# value = 2
# value = 5
# value = 139
# value = 6
# value = 4
# value = 8
# value = 7
# value = 9
# twins collection = {'39': ['A7']}
# value = 389
# value = 4
# value = 7
# value = 1359
# value = 58
# twins = {'58': ['E8']}
# value = 13589
# value = 159
# value = 6
# value = 2
# twins collection = {'58': ['E8']}
# value = 1
# value = 89
# twins = {'89': ['B9']}
# value = 6
# value = 2
# value = 7
# value = 2589
# value = 59
# twins = {'89': ['B9'], '59': ['G9']}
# value = 4
# value = 3
# twins collection = {'89': ['B9'], '59': ['G9']}
# value = 2
# value = 6
# value = 3789
# value = 589
# value = 5
# value = 3789
# value = 4
# value = 89
# twins = {'89': ['C2']}
# value = 1
# twins collection = {'89': ['C2']}
# value = 3789
# value = 4
# value = 5
# value = 3789
# value = 1
# value = 6
# value = 389
# value = 2
# value = 39
# twins = {'39': ['C6']}
# twins collection = {'39': ['C6']}
# value = 39
# twins = {'39': ['A7']}
# value = 389
# value = 1
# value = 2
# value = 4
# value = 89
# twins = {'39': ['A7'], '89': ['B9']}
# value = 5
# value = 7
# value = 6
# twins collection = {'39': ['A7'], '89': ['B9']}
# value = 159
# value = 7
# value = 6
# value = 3
# value = 58
# twins = {'58': ['E2']}
# value = 4
# value = 1589
# value = 2
# value = 89
# twins = {'58': ['E2'], '89': ['F3']}
# twins collection = {'58': ['E2'], '89': ['F3']}
# value = 4
# value = 35
# twins = {'35': ['D5']}
# value = 8
# value = 1
# value = 9
# value = 2
# value = 6
# value = 35
# twins = {'35': ['D5', 'F5']}
# value = 7
# twins collection = {'35': ['D5', 'F5']}
# ************ twin pairs founded!! =  35 ************
#   2     6    3789 | 3789   4     5   |  39   389    1
#  589    5    3789 | 3789   1     6   |  2     4     89
#   4     89    1   | 389    2     39  |  5     7     6
# ------------------+------------------+------------------
#  159    7     6   |  4     35    8   | 139   1359   2
#   3     58    4   |  1     9     2   |  6     58    7
#  1589   2     89  |  6     35    7   |  4   13589  2589
# ------------------+------------------+------------------
#   6     4     2   | 379    7    139  |  8    159    59
#   19    3     5   |  2     8     19  |  7     6     4
#   7     1     8   |  5     6     4   |  9     2     3
# value = 139
# value = 1359
# value = 2
# value = 6
# value = 58
# twins = {'58': ['E8']}
# value = 7
# value = 4
# value = 13589
# value = 2589
# twins collection = {'58': ['E8']}
# value = 6
# value = 4
# value = 2
# value = 19
# twins = {'19': ['H1']}
# value = 3
# value = 5
# value = 7
# value = 1
# value = 8
# twins collection = {'19': ['H1']}
# value = 379
# value = 7
# value = 139
# value = 2
# value = 8
# value = 19
# twins = {'19': ['H6']}
# value = 5
# value = 6
# value = 4
# twins collection = {'19': ['H6']}
# value = 8
# value = 159
# value = 59
# twins = {'59': ['G9']}
# value = 7
# value = 6
# value = 4
# value = 9
# value = 2
# value = 3
# twins collection = {'59': ['G9']}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# value = 2
# value = 6
# value = 37
# twins = {'37': ['A3']}
# value = 3789
# value = 4
# value = 5
# value = 3
# value = 8
# value = 1
# twins collection = {'37': ['A3']}
# value = 8
# value = 5
# value = 37
# twins = {'37': ['B3']}
# value = 3789
# value = 1
# value = 6
# value = 2
# value = 4
# value = 9
# twins collection = {'37': ['B3']}
# value = 4
# value = 9
# value = 1
# value = 8
# value = 2
# value = 3
# value = 5
# value = 7
# value = 6
# twins collection = {}
# value = 15
# twins = {'15': ['D1']}
# value = 7
# value = 6
# value = 4
# value = 35
# twins = {'15': ['D1'], '35': ['D5']}
# value = 8
# value = 1
# value = 9
# value = 2
# twins collection = {'15': ['D1'], '35': ['D5']}
# value = 3
# value = 8
# value = 4
# value = 1
# value = 9
# value = 2
# value = 6
# value = 5
# value = 7
# twins collection = {}
# value = 15
# twins = {'15': ['F1']}
# value = 2
# value = 9
# value = 6
# value = 35
# twins = {'15': ['F1'], '35': ['F5']}
# value = 7
# value = 4
# value = 3
# value = 8
# twins collection = {'15': ['F1'], '35': ['F5']}
# value = 6
# value = 4
# value = 2
# value = 39
# twins = {'39': ['G4']}
# value = 7
# value = 139
# value = 8
# value = 1
# value = 5
# twins collection = {'39': ['G4']}
# value = 9
# value = 3
# value = 5
# value = 2
# value = 8
# value = 1
# value = 7
# value = 6
# value = 4
# twins collection = {}
# value = 7
# value = 1
# value = 8
# value = 5
# value = 6
# value = 4
# value = 9
# value = 2
# value = 3
# twins collection = {}
# value = 2
# value = 8
# value = 4
# value = 15
# twins = {'15': ['D1']}
# value = 3
# value = 15
# twins = {'15': ['D1', 'F1']}
# value = 6
# value = 9
# value = 7
# twins collection = {'15': ['D1', 'F1']}
# ************ twin pairs founded!! =  15 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 6
# value = 5
# value = 9
# value = 7
# value = 8
# value = 2
# value = 4
# value = 3
# value = 1
# twins collection = {}
# value = 37
# twins = {'37': ['A3']}
# value = 37
# twins = {'37': ['A3', 'B3']}
# value = 1
# value = 6
# value = 4
# value = 9
# value = 2
# value = 5
# value = 8
# twins collection = {'37': ['A3', 'B3']}
# ************ twin pairs founded!! =  37 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 3789
# value = 3789
# value = 8
# value = 4
# value = 1
# value = 6
# value = 39
# twins = {'39': ['G4']}
# value = 2
# value = 5
# twins collection = {'39': ['G4']}
# value = 4
# value = 1
# value = 2
# value = 35
# twins = {'35': ['D5']}
# value = 9
# value = 35
# twins = {'35': ['D5', 'F5']}
# value = 7
# value = 8
# value = 6
# twins collection = {'35': ['D5', 'F5']}
# ************ twin pairs founded!! =  35 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 5
# value = 6
# value = 3
# value = 8
# value = 2
# value = 7
# value = 139
# value = 1
# value = 4
# twins collection = {}
# value = 3
# value = 2
# value = 5
# value = 1
# value = 6
# value = 4
# value = 8
# value = 7
# value = 9
# twins collection = {}
# value = 8
# value = 4
# value = 7
# value = 9
# value = 5
# value = 3
# value = 1
# value = 6
# value = 2
# twins collection = {}
# value = 1
# value = 9
# value = 6
# value = 2
# value = 7
# value = 8
# value = 5
# value = 4
# value = 3
# twins collection = {}
# value = 2
# value = 6
# value = 37
# twins = {'37': ['A3']}
# value = 8
# value = 5
# value = 37
# twins = {'37': ['A3', 'B3']}
# value = 4
# value = 9
# value = 1
# twins collection = {'37': ['A3', 'B3']}
# ************ twin pairs founded!! =  37 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 3789
# value = 4
# value = 5
# value = 3789
# value = 1
# value = 6
# value = 8
# value = 2
# value = 3
# twins collection = {}
# value = 3
# value = 8
# value = 1
# value = 2
# value = 4
# value = 9
# value = 5
# value = 7
# value = 6
# twins collection = {}
# value = 15
# twins = {'15': ['D1']}
# value = 7
# value = 6
# value = 3
# value = 8
# value = 4
# value = 15
# twins = {'15': ['D1', 'F1']}
# value = 2
# value = 9
# twins collection = {'15': ['D1', 'F1']}
# ************ twin pairs founded!! =  15 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 4
# value = 35
# twins = {'35': ['D5']}
# value = 8
# value = 1
# value = 9
# value = 2
# value = 6
# value = 35
# twins = {'35': ['D5', 'F5']}
# value = 7
# twins collection = {'35': ['D5', 'F5']}
# ************ twin pairs founded!! =  35 ************
#   2    6    37 | 3789  4    5  |  3    8    1
#   8    5    37 | 3789  1    6  |  2    4    9
#   4    9    1  |  8    2    3  |  5    7    6
# ---------------+---------------+---------------
#   15   7    6  |  4    35   8  |  1    9    2
#   3    8    4  |  1    9    2  |  6    5    7
#   15   2    9  |  6    35   7  |  4    3    8
# ---------------+---------------+---------------
#   6    4    2  |  39   7   139 |  8    1    5
#   9    3    5  |  2    8    1  |  7    6    4
#   7    1    8  |  5    6    4  |  9    2    3
# value = 1
# value = 9
# value = 2
# value = 6
# value = 5
# value = 7
# value = 4
# value = 3
# value = 8
# twins collection = {}
# value = 6
# value = 4
# value = 2
# value = 9
# value = 3
# value = 5
# value = 7
# value = 1
# value = 8
# twins collection = {}
# value = 39
# twins = {'39': ['G4']}
# value = 7
# value = 139
# value = 2
# value = 8
# value = 1
# value = 5
# value = 6
# value = 4
# twins collection = {'39': ['G4']}
# value = 8
# value = 1
# value = 5
# value = 7
# value = 6
# value = 4
# value = 9
# value = 2
# value = 3
# twins collection = {}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# value = 2
# value = 6
# value = 7
# value = 9
# value = 4
# value = 5
# value = 3
# value = 8
# value = 1
# twins collection = {}
# value = 8
# value = 5
# value = 3
# value = 7
# value = 1
# value = 6
# value = 2
# value = 4
# value = 9
# twins collection = {}
# value = 4
# value = 9
# value = 1
# value = 8
# value = 2
# value = 3
# value = 5
# value = 7
# value = 6
# twins collection = {}
# value = 5
# value = 7
# value = 6
# value = 4
# value = 3
# value = 8
# value = 1
# value = 9
# value = 2
# twins collection = {}
# value = 3
# value = 8
# value = 4
# value = 1
# value = 9
# value = 2
# value = 6
# value = 5
# value = 7
# twins collection = {}
# value = 1
# value = 2
# value = 9
# value = 6
# value = 5
# value = 7
# value = 4
# value = 3
# value = 8
# twins collection = {}
# value = 6
# value = 4
# value = 2
# value = 3
# value = 7
# value = 9
# value = 8
# value = 1
# value = 5
# twins collection = {}
# value = 9
# value = 3
# value = 5
# value = 2
# value = 8
# value = 1
# value = 7
# value = 6
# value = 4
# twins collection = {}
# value = 7
# value = 1
# value = 8
# value = 5
# value = 6
# value = 4
# value = 9
# value = 2
# value = 3
# twins collection = {}
# value = 2
# value = 8
# value = 4
# value = 5
# value = 3
# value = 1
# value = 6
# value = 9
# value = 7
# twins collection = {}
# value = 6
# value = 5
# value = 9
# value = 7
# value = 8
# value = 2
# value = 4
# value = 3
# value = 1
# twins collection = {}
# value = 7
# value = 3
# value = 1
# value = 6
# value = 4
# value = 9
# value = 2
# value = 5
# value = 8
# twins collection = {}
# value = 9
# value = 7
# value = 8
# value = 4
# value = 1
# value = 6
# value = 3
# value = 2
# value = 5
# twins collection = {}
# value = 4
# value = 1
# value = 2
# value = 3
# value = 9
# value = 5
# value = 7
# value = 8
# value = 6
# twins collection = {}
# value = 5
# value = 6
# value = 3
# value = 8
# value = 2
# value = 7
# value = 9
# value = 1
# value = 4
# twins collection = {}
# value = 3
# value = 2
# value = 5
# value = 1
# value = 6
# value = 4
# value = 8
# value = 7
# value = 9
# twins collection = {}
# value = 8
# value = 4
# value = 7
# value = 9
# value = 5
# value = 3
# value = 1
# value = 6
# value = 2
# twins collection = {}
# value = 1
# value = 9
# value = 6
# value = 2
# value = 7
# value = 8
# value = 5
# value = 4
# value = 3
# twins collection = {}
# value = 2
# value = 6
# value = 7
# value = 8
# value = 5
# value = 3
# value = 4
# value = 9
# value = 1
# twins collection = {}
# value = 9
# value = 4
# value = 5
# value = 7
# value = 1
# value = 6
# value = 8
# value = 2
# value = 3
# twins collection = {}
# value = 3
# value = 8
# value = 1
# value = 2
# value = 4
# value = 9
# value = 5
# value = 7
# value = 6
# twins collection = {}
# value = 5
# value = 7
# value = 6
# value = 3
# value = 8
# value = 4
# value = 1
# value = 2
# value = 9
# twins collection = {}
# value = 4
# value = 3
# value = 8
# value = 1
# value = 9
# value = 2
# value = 6
# value = 5
# value = 7
# twins collection = {}
# value = 1
# value = 9
# value = 2
# value = 6
# value = 5
# value = 7
# value = 4
# value = 3
# value = 8
# twins collection = {}
# value = 6
# value = 4
# value = 2
# value = 9
# value = 3
# value = 5
# value = 7
# value = 1
# value = 8
# twins collection = {}
# value = 3
# value = 7
# value = 9
# value = 2
# value = 8
# value = 1
# value = 5
# value = 6
# value = 4
# twins collection = {}
# value = 8
# value = 1
# value = 5
# value = 7
# value = 6
# value = 4
# value = 9
# value = 2
# value = 3
# twins collection = {}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# value = 2
# value = 5
# value = 1
# value = 4
# value = 9
# value = 7
# value = 8
# value = 6
# value = 3
# twins collection = {}
# {'A1': '2', 'A2': '6', 'A3': '7', 'A4': '9', 'A5': '4', 'A6': '5', 'A7': '3', 'A8': '8', 'A9': '1', 'B1': '8', 'B2': '5', 'B3': '3', 'B4': '7', 'B5': '1', 'B6': '6', 'B7': '2', 'B8': '4', 'B9': '9', 'C1': '4', 'C2': '9', 'C3': '1', 'C4': '8', 'C5': '2', 'C6': '3', 'C7': '5', 'C8': '7', 'C9': '6', 'D1': '5', 'D2': '7', 'D3': '6', 'D4': '4', 'D5': '3', 'D6': '8', 'D7': '1', 'D8': '9', 'D9': '2', 'E1': '3', 'E2': '8', 'E3': '4', 'E4': '1', 'E5': '9', 'E6': '2', 'E7': '6', 'E8': '5', 'E9': '7', 'F1': '1', 'F2': '2', 'F3': '9', 'F4': '6', 'F5': '5', 'F6': '7', 'F7': '4', 'F8': '3', 'F9': '8', 'G1': '6', 'G2': '4', 'G3': '2', 'G4': '3', 'G5': '7', 'G6': '9', 'G7': '8', 'G8': '1', 'G9': '5', 'H1': '9', 'H2': '3', 'H3': '5', 'H4': '2', 'H5': '8', 'H6': '1', 'H7': '7', 'H8': '6', 'H9': '4', 'I1': '7', 'I2': '1', 'I3': '8', 'I4': '5', 'I5': '6', 'I6': '4', 'I7': '9', 'I8': '2', 'I9': '3'}
# {'A1': '2', 'A2': '6', 'A3': '7', 'A4': '9', 'A5': '4', 'A6': '5', 'A7': '3', 'A8': '8', 'A9': '1', 'B1': '8', 'B2': '5', 'B3': '3', 'B4': '7', 'B5': '1', 'B6': '6', 'B7': '2', 'B8': '4', 'B9': '9', 'C1': '4', 'C2': '9', 'C3': '1', 'C4': '8', 'C5': '2', 'C6': '3', 'C7': '5', 'C8': '7', 'C9': '6', 'D1': '5', 'D2': '7', 'D3': '6', 'D4': '4', 'D5': '3', 'D6': '8', 'D7': '1', 'D8': '9', 'D9': '2', 'E1': '3', 'E2': '8', 'E3': '4', 'E4': '1', 'E5': '9', 'E6': '2', 'E7': '6', 'E8': '5', 'E9': '7', 'F1': '1', 'F2': '2', 'F3': '9', 'F4': '6', 'F5': '5', 'F6': '7', 'F7': '4', 'F8': '3', 'F9': '8', 'G1': '6', 'G2': '4', 'G3': '2', 'G4': '3', 'G5': '7', 'G6': '9', 'G7': '8', 'G8': '1', 'G9': '5', 'H1': '9', 'H2': '3', 'H3': '5', 'H4': '2', 'H5': '8', 'H6': '1', 'H7': '7', 'H8': '6', 'H9': '4', 'I1': '7', 'I2': '1', 'I3': '8', 'I4': '5', 'I5': '6', 'I6': '4', 'I7': '9', 'I8': '2', 'I9': '3'}
# 2 6 7 |9 4 5 |3 8 1
# 8 5 3 |7 1 6 |2 4 9
# 4 9 1 |8 2 3 |5 7 6
# ------+------+------
# 5 7 6 |4 3 8 |1 9 2
# 3 8 4 |1 9 2 |6 5 7
# 1 2 9 |6 5 7 |4 3 8
# ------+------+------
# 6 4 2 |3 7 9 |8 1 5
# 9 3 5 |2 8 1 |7 6 4
# 7 1 8 |5 6 4 |9 2 3
# We could not visualize your board due to a pygame issue. Not a problem! It is not a requirement.
